# %% [markdown]
# # Analysis of Model Weights

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
import requests
import pickle
import numpy as np
import pandas as pd
from pathlib import Path
from datetime import datetime
from src.nlp.generate_lyrics import DeepLyric

# %% [markdown]
# ## 4.2-LM-108k-lines-genre-song_title

# %% [markdown]
# ### Load Model

# %%
MODEL = '4.2-LM-108k-lines-genre-song_title'

# %%
model_url = f'https://storage.googleapis.com/w210-capstone/models/{MODEL}_architecture.pkl'
model = requests.get(model_url)
model = model.content
model = pickle.loads(model)

# %%
itos_url = f'https://storage.googleapis.com/w210-capstone/models/{MODEL}_itos.pkl'
itos = requests.get(itos_url)
itos = itos.content
itos = pickle.loads(itos)

# %% [markdown]
# #### Stop Words

# %%
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/syang/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words = set(stopwords.words('english')) 
stop_words.add("'t")
stop_words.add("'ll")
stop_words.add("’t")
stop_words.add("'ve")
stop_words.add(",")
stop_words.add("'s")
stop_words.add("'re")
stop_words.add("'m")
stop_words.add("don")
stop_words.add("won")
stop_words.add("xbol")
stop_words.add("xbos")
stop_words.add("xeol")
stop_words.add("xeos")
stop_words.add("xgenre")
stop_words.add("xtitle")
for i in range(1,100):
    stop_words.add(f"xbol-{i}")
stop_words.add("[verse-1]")
stop_words.add("[intro]")
stop_words.add("(album")

# %%
deep_lyric = DeepLyric(model, itos=itos, model_type='language')

# %% [markdown]
# ### Next Word Distribution

# %% [markdown]
# Genre #1

# %%
next_word_probs = deep_lyric.get_predicted_probs(seed_text='xbos xgenre oldies xtitle', 
                         verbose=0, context_length=50, beam_width=1000,
                         max_len=5, top_k=100, temperature=1., multinomial=False,
                         GPU=True)

next_word_probs = [s for s in next_word_probs if s[1] not in stop_words]

df = pd.DataFrame(next_word_probs, columns=['context', 'next_word', 'probability'])
df.shape
# Out:
# (360300, 3)

# %%
top_words_1 = df.groupby('next_word').sum().sort_values(by='probability', ascending=False)
top_words_1.head(10)
# Out:
#            probability
# next_word
# love          8.063945
# one           5.303190
# baby          4.166161
# know          3.346304
# darling       2.762380
# go            2.725564
# little        2.284754
# gone          2.283052
# girl          2.057671
# want          2.032918

# %% [markdown]
# Genre #2

# %%
next_word_probs = deep_lyric.get_predicted_probs(seed_text='xbos xgenre death metal xtitle', 
                         verbose=0, context_length=50, beam_width=1000,
                         max_len=5, top_k=100, temperature=1., multinomial=False,
                         GPU=True)

next_word_probs = [s for s in next_word_probs if s[1] not in stop_words]

df = pd.DataFrame(next_word_probs, columns=['context', 'next_word', 'probability'])
df.shape
# Out:
# (369033, 3)

# %%
top_words_2 = df.groupby('next_word').sum().sort_values(by='probability', ascending=False)
top_words_2.head(10)
# Out:
#            probability
# next_word
# death         4.420793
# world         4.418909
# black         3.259346
# dead          2.960679
# night         1.971365
# war           1.816822
# evil          1.739159
# hell          1.698340
# life          1.674410
# end           1.638543

# %%
df_combined = pd.merge(top_words_1, top_words_2, how='outer', left_index=True, right_index=True)
# df_combined['rel_ratio_abs'] = (df_combined['probability_x'] / df_combined['probability_y'])
df_combined['diff'] = df_combined['probability_x'] - df_combined['probability_y']
df_combined['diff_abs'] = np.abs(df_combined['diff'])
df_combined['rel_diff_abs'] = df_combined['diff_abs'] / df_combined['probability_x']
df_combined.sort_values(by='rel_diff_abs', ascending=False)\
    .loc[df_combined['diff'] > 0, :]
# Out:
#                probability_x  probability_y          diff      diff_abs  \
# next_word
# marie               0.026983   2.334066e-06  2.698024e-02  2.698024e-02
# downtown            0.042128   1.420305e-05  4.211331e-02  4.211331e-02
# babe                0.130177   6.084398e-05  1.301164e-01  1.301164e-01
# tennessee           0.014239   7.910537e-06  1.423126e-02  1.423126e-02
# georgia             0.013158   8.511978e-06  1.314957e-02  1.314957e-02
# gal                 0.053483   3.694148e-05  5.344582e-02  5.344582e-02
# darling             2.762380   2.028313e-03  2.760352e+00  2.760352e+00
# ooo                 0.004086   3.117769e-06  4.082936e-03  4.082936e-03
# doo                 0.004206   3.255128e-06  4.202258e-03  4.202258e-03
# dancin              0.046226   3.604081e-05  4.618946e-02  4.618946e-02
# honey               0.415413   3.347647e-04  4.150781e-01  4.150781e-01
# sugar               0.057690   5.216780e-05  5.763737e-02  5.763737e-02
# tho                 0.001864   1.712249e-06  1.862516e-03  1.862516e-03
# rosie               0.002539   2.982539e-06  2.535527e-03  2.535527e-03
# pa                  0.003875   4.872882e-06  3.869786e-03  3.869786e-03
# joe                 0.051251   6.689123e-05  5.118387e-02  5.118387e-02
# untrue              0.030475   4.123386e-05  3.043378e-02  3.043378e-02
# lovin               0.260751   3.863412e-04  2.603644e-01  2.603644e-01
# ev                  0.021003   4.557766e-05  2.095758e-02  2.095758e-02
# faithfully          0.001182   2.610301e-06  1.179841e-03  1.179841e-03
# (oh,                0.004921   1.127460e-05  4.910196e-03  4.910196e-03
# robin               0.015668   3.589826e-05  1.563212e-02  1.563212e-02
# ei                  0.000309   7.232309e-07  3.087490e-04  3.087490e-04
# bop                 0.004706   1.150637e-05  4.694956e-03  4.694956e-03
# sweetheart          0.145085   3.852683e-04  1.446996e-01  1.446996e-01
# dee                 0.000592   1.639573e-06  5.901892e-04  5.901892e-04
# baby                4.166161   1.302124e-02  4.153139e+00  4.153139e+00
# sincerely           0.001336   4.224506e-06  1.331752e-03  1.331752e-03
# james               0.003813   1.207168e-05  3.801320e-03  3.801320e-03
# h                   0.000971   3.190281e-06  9.681108e-04  9.681108e-04
# ...                      ...            ...           ...           ...
# moi                 0.000748   7.272482e-04  2.111503e-05  2.111503e-05
# (solo)              0.000386   3.760540e-04  1.009104e-05  1.009104e-05
# fingers             0.009350   9.119002e-03  2.311914e-04  2.311914e-04
# guard               0.001380   1.347686e-03  3.250944e-05  3.250944e-05
# communication       0.000426   4.160894e-04  9.612631e-06  9.612631e-06
# read                0.014574   1.425421e-02  3.200101e-04  3.200101e-04
# discovered          0.000544   5.318922e-04  1.172462e-05  1.172462e-05
# drifting            0.004238   4.146970e-03  9.104558e-05  9.104558e-05
# chemistry           0.000222   2.177662e-04  4.092496e-06  4.092496e-06
# closed              0.005249   5.152934e-03  9.558581e-05  9.558581e-05
# almost              0.016916   1.660986e-02  3.060535e-04  3.060535e-04
# charade             0.000908   8.926210e-04  1.583948e-05  1.583948e-05
# (amended            0.006728   6.615722e-03  1.127234e-04  1.127234e-04
# quickly             0.005789   5.695319e-03  9.417775e-05  9.417775e-05
# suspicious          0.000338   3.325556e-04  5.386152e-06  5.386152e-06
# brightly            0.000222   2.191909e-04  3.277087e-06  3.277087e-06
# sunrise             0.015223   1.500886e-02  2.143815e-04  2.143815e-04
# vacant              0.000686   6.767161e-04  9.032527e-06  9.032527e-06
# blowing             0.000952   9.406309e-04  1.148999e-05  1.148999e-05
# knowing             0.010190   1.008822e-02  1.020625e-04  1.020625e-04
# praying             0.004240   4.201555e-03  3.813841e-05  3.813841e-05
# pulls               0.001201   1.191398e-03  9.140861e-06  9.140861e-06
# loose               0.021346   2.118701e-02  1.593498e-04  1.593498e-04
# lay                 0.065535   6.515716e-02  3.774256e-04  3.774256e-04
# start               0.057875   5.756167e-02  3.133898e-04  3.133898e-04
# costs               0.000102   1.017096e-04  4.992014e-07  4.992014e-07
# verte               0.000267   2.658322e-04  1.271767e-06  1.271767e-06
# seen                0.066407   6.628556e-02  1.213863e-04  1.213863e-04
# chorus              0.026269   2.624447e-02  2.423450e-05  2.423450e-05
# reckon              0.000533   5.325955e-04  1.712219e-07  1.712219e-07
#
#                rel_diff_abs
# next_word
# marie              0.999913
# downtown           0.999663
# babe               0.999533
# tennessee          0.999444
# georgia            0.999353
# gal                0.999309
# darling            0.999266
# ooo                0.999237
# doo                0.999226
# dancin             0.999220
# honey              0.999194
# sugar              0.999096
# tho                0.999082
# rosie              0.998825
# pa                 0.998742
# joe                0.998695
# untrue             0.998647
# lovin              0.998518
# ev                 0.997830
# faithfully         0.997792
# (oh,               0.997709
# robin              0.997709
# ei                 0.997663
# bop                0.997555
# sweetheart         0.997345
# dee                0.997230
# baby               0.996875
# sincerely          0.996838
# james              0.996834
# h                  0.996715
# ...                     ...
# moi                0.028215
# (solo)             0.026133
# fingers            0.024726
# guard              0.023554
# communication      0.022581
# read               0.021957
# discovered         0.021568
# drifting           0.021483
# chemistry          0.018446
# closed             0.018212
# almost             0.018093
# charade            0.017436
# (amended           0.016753
# quickly            0.016267
# suspicious         0.015938
# brightly           0.014731
# sunrise            0.014083
# vacant             0.013172
# blowing            0.012068
# knowing            0.010016
# praying            0.008996
# pulls              0.007614
# loose              0.007465
# lay                0.005759
# start              0.005415
# costs              0.004884
# verte              0.004761
# seen               0.001828
# chorus             0.000923
# reckon             0.000321
#
# [2889 rows x 5 columns]

# %% [markdown]
# ## 4.2-MM-108k-post

# %% [markdown]
# ### Load Model

# %%
MODEL = '4.2-MM-108k-post'

# %%
model_url = f'https://storage.googleapis.com/w210-capstone/models/{MODEL}_architecture.pkl'
model = requests.get(model_url)
model = model.content
model = pickle.loads(model)

# %%
itos_url = f'https://storage.googleapis.com/w210-capstone/models/{MODEL}_itos.pkl'
itos = requests.get(itos_url)
itos = itos.content
itos = pickle.loads(itos)

# %%
deep_lyric = DeepLyric(model, itos=itos, model_type='multimodal')

# %%
genre_ohe = np.zeros((1, 24))
genre_ohe[0][23] = 1

# %%
deep_lyric.generate_text(seed_text=['xbos', 'xbol-1'], 
                         verbose=0, context_length=100, beam_width=3,
                         max_len=100, top_k=5, temperature=1.45,
                         GPU=True, audio=genre_ohe)

# %%
deep_lyric.print_lyrics()
# Out:
# SONG START
#
#
# xbol-1 i 'd hate to think it wouldn 't be like this
#  i wouldn 't lie to you like that
#  shouldn 't i love you like that ?
#  i don 't care , i don 't care
#  if that isn 't worth it
#  i don 't care
#  if this isn 't love
#  why wouldn 't she care ?
#
#  if that isn 't love
#  what would it be
#  if that isn 't love ?
#  if that isn 't

# %% [markdown]
# ### Next Word Distribution

# %% [markdown]
# Genre #1

# %%
genre_ohe = np.zeros((1, 24))
genre_ohe[0][23] = 1

next_word_probs = deep_lyric.get_predicted_probs(seed_text=['xbos', 'xbol-1'], 
                         verbose=0, context_length=50, beam_width=1000,
                         max_len=5, top_k=100, temperature=1., multinomial=False,
                         GPU=True, audio=genre_ohe)

next_word_probs = [s for s in next_word_probs if s[1] not in stop_words]

df = pd.DataFrame(next_word_probs, columns=['context', 'next_word', 'probability'])
df.shape
# Out:
# (359120, 3)

# %%
top_words_1 = df.groupby('next_word').sum().sort_values(by='probability', ascending=False)
top_words_1.head(10)
# Out:
#            probability
# next_word
# know          3.162330
# see           2.681370
# time          2.413892
# morning       2.248662
# love          2.153535
# got           1.964642
# go            1.894376
# tell          1.893202
# long          1.893187
# little        1.810010

# %% [markdown]
# Genre #2

# %%
genre_ohe = np.zeros((1, 24))
genre_ohe[0][16] = 1

next_word_probs = deep_lyric.get_predicted_probs(seed_text=['xbos', 'xbol-1'], 
                         verbose=0, context_length=50, beam_width=1000,
                         max_len=5, top_k=100, temperature=1., multinomial=False,
                         GPU=True, audio=genre_ohe)

next_word_probs = [s for s in next_word_probs if s[1] not in stop_words]

df = pd.DataFrame(next_word_probs, columns=['context', 'next_word', 'probability'])
df.shape
# Out:
# (360021, 3)

# %%
top_words_2 = df.groupby('next_word').sum().sort_values(by='probability', ascending=False)
top_words_2.head(10)
# Out:
#            probability
# next_word
# know          3.286165
# got           3.216332
# yeah          2.946051
# love          2.507336
# like          2.263979
# time          2.184132
# de            2.082353
# one           1.711553
# hey           1.646097
# see           1.624662

# %%
df_combined = pd.merge(top_words_1, top_words_2, how='outer', left_index=True, right_index=True)
# df_combined['rel_ratio_abs'] = (df_combined['probability_x'] / df_combined['probability_y'])
df_combined['diff'] = df_combined['probability_x'] - df_combined['probability_y']
df_combined['diff_abs'] = np.abs(df_combined['diff'])
df_combined['rel_diff_abs'] = df_combined['diff_abs'] / df_combined['probability_x']
df_combined.sort_values(by='rel_diff_abs', ascending=False)\
    .loc[df_combined['diff'] < 0, :]
# Out:
#               probability_x  probability_y          diff      diff_abs  \
# next_word
# xbol-125       4.939588e-08       0.000285 -2.851689e-04  2.851689e-04
# chanson        6.655138e-04       1.005610 -1.004944e+00  1.004944e+00
# bist           8.444942e-05       0.100078 -9.999354e-02  9.999354e-02
# drummer        8.642363e-06       0.009497 -9.488718e-03  9.488718e-03
# urge           1.205424e-06       0.000988 -9.867229e-04  9.867229e-04
# [estribillo]   1.965110e-06       0.001437 -1.434811e-03  1.434811e-03
# swimmin        4.473763e-06       0.002959 -2.954125e-03  2.954125e-03
# appear         8.972119e-06       0.005726 -5.716728e-03  5.716728e-03
# desires        4.643415e-06       0.002710 -2.705295e-03  2.705295e-03
# ou             7.432987e-06       0.003110 -3.102198e-03  3.102198e-03
# whoever        1.215878e-05       0.004902 -4.889365e-03  4.889365e-03
# (we            1.826608e-05       0.006399 -6.381144e-03  6.381144e-03
# tha            1.588961e-05       0.004354 -4.338558e-03  4.338558e-03
# cane           1.263557e-05       0.003262 -3.249621e-03  3.249621e-03
# stehst         7.793910e-05       0.019967 -1.988891e-02  1.988891e-02
# wishes         3.515061e-05       0.008387 -8.351776e-03  8.351776e-03
# visualize      8.586590e-06       0.001961 -1.952592e-03  1.952592e-03
# mostly         2.085002e-05       0.004696 -4.675442e-03  4.675442e-03
# "you           1.620023e-05       0.003141 -3.124984e-03  3.124984e-03
# seguir         4.571873e-05       0.007779 -7.733033e-03  7.733033e-03
# pal            9.137622e-06       0.001460 -1.451273e-03  1.451273e-03
# choices        4.711132e-05       0.007412 -7.365043e-03  7.365043e-03
# drained        8.008613e-06       0.001252 -1.244091e-03  1.244091e-03
# shiny          1.378585e-04       0.021152 -2.101457e-02  2.101457e-02
# helped         8.068520e-05       0.012224 -1.214350e-02  1.214350e-02
# dre            2.066595e-05       0.002920 -2.898905e-03  2.898905e-03
# western        6.681343e-06       0.000938 -9.310130e-04  9.310130e-04
# sorta          2.371181e-05       0.003255 -3.231072e-03  3.231072e-03
# battered       1.637957e-07       0.000022 -2.208292e-05  2.208292e-05
# hitting        2.592107e-05       0.003496 -3.469877e-03  3.469877e-03
# ...                     ...            ...           ...           ...
# hopefully      1.315209e-05       0.000013 -1.664922e-07  1.664922e-07
# keeps          2.766542e-02       0.028004 -3.385059e-04  3.385059e-04
# wicked         2.634129e-02       0.026655 -3.132996e-04  3.132996e-04
# girls          1.428242e-02       0.014444 -1.616906e-04  1.616906e-04
# illegal        1.086706e-04       0.000110 -1.177632e-06  1.177632e-06
# worldly        4.093770e-05       0.000041 -3.881174e-07  3.881174e-07
# est            4.321471e-02       0.043622 -4.075864e-04  4.075864e-04
# lui            3.682822e-03       0.003715 -3.262388e-05  3.262388e-05
# man            1.035042e+00       1.044110 -9.067930e-03  9.067930e-03
# muchacha       1.528623e-04       0.000154 -1.254334e-06  1.254334e-06
# 3x             2.483045e-04       0.000250 -1.969994e-06  1.969994e-06
# magazine       2.161867e-03       0.002178 -1.621285e-05  1.621285e-05
# pienso         1.264832e-03       0.001274 -8.905862e-06  8.905862e-06
# traición       2.562476e-04       0.000258 -1.763180e-06  1.763180e-06
# melodies       4.512112e-04       0.000454 -3.048881e-06  3.048881e-06
# escenario      1.083973e-03       0.001091 -6.751266e-06  6.751266e-06
# respect        4.158908e-03       0.004184 -2.517595e-05  2.517595e-05
# vai            4.497224e-03       0.004524 -2.709198e-05  2.709198e-05
# blinding       2.076075e-03       0.002088 -1.173540e-05  1.173540e-05
# imagined       6.929676e-04       0.000696 -3.182028e-06  3.182028e-06
# sé             2.072562e-02       0.020812 -8.615526e-05  8.615526e-05
# viento         4.185910e-02       0.042021 -1.623525e-04  1.623525e-04
# unusual        5.524917e-04       0.000554 -1.683517e-06  1.683517e-06
# firing         3.383636e-04       0.000339 -8.197318e-07  8.197318e-07
# red            6.739956e-02       0.067552 -1.525977e-04  1.525977e-04
# reaper         7.024706e-04       0.000704 -1.109251e-06  1.109251e-06
# nostalgia      6.629083e-04       0.000664 -9.428050e-07  9.428050e-07
# listen         1.407667e-01       0.140950 -1.830557e-04  1.830557e-04
# stories        3.951173e-03       0.003952 -1.292918e-06  1.292918e-06
# droppin        1.182610e-04       0.000118 -1.453067e-08  1.453067e-08
#
#               rel_diff_abs
# next_word
# xbol-125       5773.131404
# chanson        1510.027747
# bist           1184.064318
# drummer        1097.931069
# urge            818.569072
# [estribillo]    730.142836
# swimmin         660.322205
# appear          637.165945
# desires         582.608857
# ou              417.355476
# whoever         402.126457
# (we             349.343973
# tha             273.043627
# cane            257.180426
# stehst          255.185296
# wishes          237.599760
# visualize       227.400193
# mostly          224.241643
# "you            192.897463
# seguir          169.143664
# pal             158.823954
# choices         156.332761
# drained         155.344133
# shiny           152.435756
# helped          150.504702
# dre             140.274496
# western         139.345185
# sorta           136.264257
# battered        134.819907
# hitting         133.863224
# ...                    ...
# hopefully         0.012659
# keeps             0.012236
# wicked            0.011894
# girls             0.011321
# illegal           0.010837
# worldly           0.009481
# est               0.009432
# lui               0.008858
# man               0.008761
# muchacha          0.008206
# 3x                0.007934
# magazine          0.007499
# pienso            0.007041
# traición          0.006881
# melodies          0.006757
# escenario         0.006228
# respect           0.006054
# vai               0.006024
# blinding          0.005653
# imagined          0.004592
# sé                0.004157
# viento            0.003879
# unusual           0.003047
# firing            0.002423
# red               0.002264
# reaper            0.001579
# nostalgia         0.001422
# listen            0.001300
# stories           0.000327
# droppin           0.000123
#
# [4058 rows x 5 columns]
