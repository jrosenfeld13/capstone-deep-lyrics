# %%
from fastai import *
from fastai.docs import *
from fastai.text import *

# %%
# untar_data(IMDB_PATH)

# %%
df = pd.read_csv(IMDB_PATH/'train.csv', header=None)
df.head()
# Out:
#    0                                                  1
# 0  0  Un-bleeping-believable! Meg Ryan doesn't even ...
# 1  1  This is a extremely well-made film. The acting...
# 2  0  Every once in a long while a movie will come a...
# 3  1  Name just says it all. I watched this movie wi...
# 4  0  This movie succeeds at being one of the most u...

# %%
classes = read_classes(IMDB_PATH/'classes.txt')
classes[0], classes[1]
# Out:
# ('negative', 'positive')

# %%
data_lm = text_data_from_csv(Path(IMDB_PATH), data_func=lm_data)
# data_lm = text_data_from_csv(Path(IMDB_PATH))

# %%
list(iter(data_lm.train_dl))
# Out:
# [[tensor([[  42, 2435,    0,  ...,   16,   21,   27],
#           [  39,    9,   21,  ...,  819,    0,   11],
#           [4612,    0,    6,  ...,   13,   16,   80],
#           ...,
#           [   9,    8,    3,  ...,   22,    2,  727],
#           [   6,  404,   24,  ...,    5, 1913,   61],
#           [ 595,   10,   13,  ..., 1239,  219,   30]], device='cuda:0'),
#   tensor([  39,    9,   21,  ...,   10, 1182, 4604], device='cuda:0')],
#  [tensor([[  88,   54,   17,  ...,   10, 1182, 4604],
#           [  18,   23,   29,  ...,  184,    3,   27],
#           [ 113,    0,    2,  ...,    3,  104,    5],
#           ...,
#           [  45,   68, 2459,  ...,  548,    4,   14],
#           [ 425,   42,    3,  ...,   51,    2,   38],
#           [ 332,   39,   12,  ...,    2,   25,    9]], device='cuda:0'),
#   tensor([  18,   23,   29,  ..., 1522,    9,   35], device='cuda:0')],
#  [tensor([[  23,   30,  120,  ..., 1522,    9,   35],
#           [   2, 1974,   14,  ..., 1182, 2670,   72],
#           [ 246,   87,   22,  ...,    7, 2155,    6],
#           ...,
#           [3776,  149,  118,  ...,  137,    2,    8],
#           [   8,   23,  165,  ...,    5,  608,  185],
#           [   0,   34,   21,  ...,  788,    7,   43]], device='cuda:0'),
#   tensor([   2, 1974,   14,  ...,    0,    2,    5], device='cuda:0')],
#  [tensor([[ 233,   61,    0,  ...,    0,    2,    5],
#           [  97,  133,  123,  ...,   53,  920,  163],
#           [  20,   18,  768,  ...,    8,  461,   78],
#           ...,
#           [  20,    0,  706,  ...,  116,   85,    2],
#           [   6,  110,   45,  ...,   32,    2,  319],
#           [ 322,   11, 4707,  ..., 2066,   25,  381]], device='cuda:0'),
#   tensor([  97,  133,  123,  ...,    4,    4, 4406], device='cuda:0')],
#  [tensor([[  18,   34,    8,  ...,    4,    4, 4406],
#           [   5,    0, 1687,  ...,   52,   10,  149],
#           [  18,  282, 1021,  ...,   32,   16,   38],
#           ...,
#           [   0,    0,   23,  ...,   13,  181,    9],
#           [  59,   18,   59,  ...,   47,  373,    6],
#           [   4,    0,  283,  ...,   59,   44,  828]], device='cuda:0'),
#   tensor([   5,    0, 1687,  ...,   11,  750,   57], device='cuda:0')],
#  [tensor([[ 108,  536,   20,  ...,   11,  750,   57],
#           [ 281,  849,    6,  ...,  156, 1454,  107],
#           [ 242,   43, 1564,  ...,  340,    3,   43],
#           ...,
#           [ 118,    0,  435,  ...,    6,    6,  932],
#           [4616,   31,    8,  ...,   22,  219,  653],
#           [1668,  303,   36,  ...,    3,  118,   12]], device='cuda:0'),
#   tensor([281, 849,   6,  ...,  69, 811,  17], device='cuda:0')],
#  [tensor([[   3,    9,   76,  ...,   69,  811,   17],
#           [  11,  775,    6,  ...,   60,   83,  263],
#           [  13,   46,    0,  ...,    8,    0, 1240],
#           ...,
#           [  39,   42,    0,  ...,  246, 1358,    3],
#           [ 209,   39,    0,  ...,   60,   16, 2733],
#           [ 323,   12, 4711,  ...,    2,  238,  577]], device='cuda:0'),
#   tensor([ 11, 775,   6,  ...,   0,  60, 932], device='cuda:0')],
#  [tensor([[  11,   36,  848,  ...,    0,   60,  932],
#           [   6,  263,   66,  ...,    7,    6,    9],
#           [ 248,  387,   20,  ...,    6, 5134,    2],
#           ...,
#           [ 628,  212,    0,  ...,   60,  538,   92],
#           [  24,    6,   30,  ...,   76,    4,    2],
#           [  38,   22,   45,  ..., 1581,   23, 4191]], device='cuda:0'),
#   tensor([   6,  263,   66,  ..., 1172,  664,    0], device='cuda:0')],
#  [tensor([[1670,   13,    0,  ..., 1172,  664,    0],
#           [  46,  435,    7,  ...,  130,    0,  100],
#           [ 161,    8, 1021,  ...,    2,  192,   56],
#           ...,
#           [ 503, 2193,  120,  ...,   18,  122,   44],
#           [   3,    8,    2,  ..., 1695,   10, 5538],
#           [   2,  429, 3859,  ...,   31, 1020,    5]], device='cuda:0'),
#   tensor([ 46, 435,   7,  ..., 930, 156,  34], device='cuda:0')],
#  [tensor([[ 246,   11, 1293,  ...,  930,  156,   34],
#           [ 395,  116,    9,  ...,   22,   63,  584],
#           [  20,    4,    6,  ...,    3, 2042,    4],
#           ...,
#           [   2,    3,   10,  ...,   20,   70,  131],
#           [1001,    2,   16,  ...,  102,   37,  577],
#           [  21,   83,    6,  ...,   20,    0,   16]], device='cuda:0'),
#   tensor([395, 116,   9,  ..., 214,   3, 550], device='cuda:0')],
#  [tensor([[  14,    7,   72,  ...,  214,    3,  550],
#           [  22, 1046,   98,  ...,  105,   52,  988],
#           [3197,    0,   25,  ...,   97,   17,    6],
#           ...,
#           [ 133,   23,   12,  ..., 3190,  267,  312],
#           [   3,  425,  659,  ...,    9,   21,   44],
#           [   2,  172, 4717,  ..., 5989,   10,  182]], device='cuda:0'),
#   tensor([  22, 1046,   98,  ...,    4,    4,  136], device='cuda:0')],
#  [tensor([[1671,    5,  813,  ...,    4,    4,  136],
#           [ 176,   45,    7,  ...,   45,   24,  495],
#           [  51,  425,  265,  ..., 5763,   12,    8],
#           ...,
#           [   2,  531,   11,  ..., 1228,    6,    4],
#           [  22,  247, 1836,  ...,    5, 3941,   24],
#           [  15,  267,    2,  ...,   36,   61, 4421]], device='cuda:0'),
#   tensor([ 176,   45,    7,  ...,   10,    4, 2958], device='cuda:0')],
#  [tensor([[2418,    3,   22,  ...,   10,    4, 2958],
#           [   4,   40,   17,  ..., 1914,   61,    3],
#           [2419,   32, 3860,  ...,   44,   10,  407],
#           ...,
#           [   7,    4, 4721,  ...,  146,   12,    2],
#           [   2,   24,    5,  ...,    2,  175, 1895],
#           [ 133,   93, 4720,  ..., 3190,   35,    7]], device='cuda:0'),
#   tensor([  4,  40,  17,  ..., 481,   6,   0], device='cuda:0')],
#  [tensor([[   3,   43, 1274,  ...,  481,    6,    0],
#           [  42,    2,  273,  ...,    8,  215,  401],
#           [  39,  181,    4,  ..., 4377,  391,   85],
#           ...,
#           [  55,   21,    4,  ...,  642,  811,    8],
#           [  26, 1157,   38,  ...,    7,   20, 3517],
#           [  56,   18,    7,  ...,  114,   10,   59]], device='cuda:0'),
#   tensor([ 42,   2, 273,  ...,  36,   9, 319], device='cuda:0')],
#  [tensor([[  29, 3826,    2,  ...,   36,    9,  319],
#           [ 191, 2444,   63,  ...,  150,   45,   23],
#           [   8,    8, 3861,  ...,   72,  192,    0],
#           ...,
#           [   3,   12,    0,  ...,    3,    4,  162],
#           [  12,  387,    4,  ...,    2,   14,  142],
#           [ 213,  110,    0,  ...,   83,    0,   23]], device='cuda:0'),
#   tensor([ 191, 2444,   63,  ...,   93,  357, 1635], device='cuda:0')],
#  [tensor([[  29,  102,  721,  ...,   93,  357, 1635],
#           [ 151,  135,    0,  ...,  198, 1140,    5],
#           [  28,   11, 3863,  ...,  690,   38,   34],
#           ...,
#           [ 248,   17,    0,  ...,  468,  456,    2],
#           [   3,    6,    8,  ...,  187,    4,  241],
#           [  28,  436,    2,  ...,  416,   24,    7]], device='cuda:0'),
#   tensor([151, 135,   0,  ...,   4,  12, 132], device='cuda:0')],
#  [tensor([[ 360,  361,  705,  ...,    4,   12,  132],
#           [   7,    7,   32,  ...,   62,  262,   12],
#           [  13,  568,  389,  ...,    7,   56, 5950],
#           ...,
#           [   0,    3,    9,  ...,    4,    9,   89],
#           [   7,   10,  403,  ...,    5,  178,  501],
#           [ 412,  198,   49,  ...,    2, 1094, 4075]], device='cuda:0'),
#   tensor([   7,    7,   32,  ..., 1206,    3,    8], device='cuda:0')],
#  [tensor([[ 490,   13, 1169,  ..., 1206,    3,    8],
#           [ 232,   55,   21,  ...,   11,   12,  270],
#           [   0,   26,   59,  ...,   14,  211,   13],
#           ...,
#           [  35,   51,   19,  ...,    4,  137, 1947],
#           [   6, 2446,    0,  ...,   24,   56, 1776],
#           [  67,  249, 4730,  ...,    6,   35,   18]], device='cuda:0'),
#   tensor([ 232,   55,   21,  ..., 2954,   81,  539], device='cuda:0')],
#  [tensor([[1274,    5,  375,  ..., 2954,   81,  539],
#           [ 721,  100, 1017,  ...,   76,   36, 1572],
#           [   5,   29,    0,  ...,  156, 1224,    8],
#           ...,
#           [1146,   57,   80,  ...,   40,    9,  539],
#           [ 140, 1103,    0,  ..., 3247,    0,    4],
#           [   4,  243,  265,  ...,  336,    8,    2]], device='cuda:0'),
#   tensor([ 721,  100, 1017,  ...,    8,    2,  708], device='cuda:0')],
#  [tensor([[ 426,   36,   16,  ...,    8,    2,  708],
#           [ 111,  654,  580,  ...,    0,  127,  118],
#           [4626,   44, 1389,  ...,  269,    3,  194],
#           ...,
#           [ 270,  479,    4,  ...,   68,   82,    0],
#           [  96,    4,   20,  ...,   12,    6,   28],
#           [4627,   12, 3279,  ...,  120,   22,    2]], device='cuda:0'),
#   tensor([111, 654, 580,  ..., 389,  23, 280], device='cuda:0')],
#  [tensor([[ 647,   17,   89,  ...,  389,   23,  280],
#           [1363,  390,   78,  ..., 5133,  109,  125],
#           [  21, 1551,    0,  ...,   16,    0,   26],
#           ...,
#           [1551,    2,  137,  ...,   36,  134,  117],
#           [  98, 1104,   13,  ...,   76, 1031,  114],
#           [   3,   24, 4736,  ...,    0,  432,  185]], device='cuda:0'),
#   tensor([1363,  390,   78,  ..., 3319,    5,  374], device='cuda:0')],
#  [tensor([[1452,   12,    2,  ..., 3319,    5,  374],
#           [  32,  537, 2470,  ...,   11,   41,    5],
#           [  40,   62,    7,  ...,   75,  879,    0],
#           ...,
#           [   3,   37,    4,  ...,    5,  194,    0],
#           [   5,    6,  185,  ...,  214,  543,   24],
#           [  55,  127,   43,  ...,   54,   14,   40]], device='cuda:0'),
#   tensor([  32,  537, 2470,  ...,   18,   22,   36], device='cuda:0')],
#  [tensor([[  40,  199,    2,  ...,   18,   22,   36],
#           [ 247,  140,  587,  ...,  974,   53,  344],
#           [   2, 1089,  126,  ..., 3319,  112,    0],
#           ...,
#           [   6,    0,   30,  ...,  409,   10,  771],
#           [ 207,   27,  153,  ...,   33,    3, 1938],
#           [   7,   49,   20,  ...,   76,   12,    3]], device='cuda:0'),
#   tensor([ 247,  140,  587,  ..., 1345,    0,   24], device='cuda:0')],
#  [tensor([[ 501,   33,   31,  ..., 1345,    0,   24],
#           [ 109,    9,    0,  ...,   34,    6, 2733],
#           [ 219,    0,   16,  ...,  399,  513,  577],
#           ...,
#           [  11,  352,   11,  ...,   39, 1878,  577],
#           [ 443,    8,   14,  ...,   10,   44,  932],
#           [ 126,   82,  355,  ...,   16,   15,   73]], device='cuda:0'),
#   tensor([109,   9,   0,  ..., 261, 953, 501], device='cuda:0')],
#  [tensor([[ 153,   13,    4,  ...,  261,  953,  501],
#           [  20,   43,    2,  ...,   13,    3,    6],
#           [   2,  227,   25,  ...,   26,   10,  109],
#           ...,
#           [ 940,    8,  172,  ..., 1790,    6,  274],
#           [ 219,  117,    3,  ...,    4,  422,   55],
#           [  22,  813,    2,  ..., 2133, 5994,   26]], device='cuda:0'),
#   tensor([20, 43,  2,  ...,  4,  4, 73], device='cuda:0')],
#  [tensor([[   3,  223, 1276,  ...,    4,    4,   73],
#           [   2,   43, 1171,  ...,    6,   50,    8],
#           [ 127,    2,   20,  ..., 1591,   60,  247],
#           ...,
#           [  43,    4,  657,  ..., 2448,   50,  899],
#           [   2,   58,    6,  ...,    5,  375,    3],
#           [ 144, 1981,  635,  ...,  252,   23,   21]], device='cuda:0'),
#   tensor([   2,   43, 1171,  ...,   62,  110,  573], device='cuda:0')],
#  [tensor([[  23,   90,    0,  ...,   62,  110,  573],
#           [  62,   10,  162,  ...,    0,  408,    4],
#           [ 352,  117,    2,  ...,    7,   33,  577],
#           ...,
#           [ 528,  124, 4743,  ...,  464,   19, 1161],
#           [   5,   14,    4,  ...,   28,    2,   23],
#           [  12,   22,    8,  ...,    2,  306,   75]], device='cuda:0'),
#   tensor([  62,   10,  162,  ..., 1056,    5, 2317], device='cuda:0')],
#  [tensor([[ 476,  274,   94,  ..., 1056,    5, 2317],
#           [  56,    4,    2,  ...,   46,   59,   12],
#           [  29,  122,  950,  ...,    6,  703,  650],
#           ...,
#           [   0,   15,    0,  ...,    0,   85,   22],
#           [  84,  143,   30,  ...,   73,  429,   11],
#           [  28,  117,    0,  ...,    0,    3,  129]], device='cuda:0'),
#   tensor([ 56,   4,   2,  ...,   5, 389, 673], device='cuda:0')],
#  [tensor([[ 103,   18,   27,  ...,    5,  389,  673],
#           [   2,   66,    5,  ...,   11,  535,    4],
#           [1552,   15,   31,  ..., 2596,  642,   80],
#           ...,
#           [   5,   33, 4746,  ...,   79,   97,    3],
#           [  76,   17,  260,  ...,  675,   92,  325],
#           [2179,  221,  398,  ...,  989,  389,   10]], device='cuda:0'),
#   tensor([ 2, 66,  5,  ...,  7,  3, 16], device='cuda:0')],
#  [tensor([[2180,  559,    3,  ...,    7,    3,   16],
#           [  92,  400,   12,  ...,  540,  389,  106],
#           [  58,   48,  387,  ...,   11,  471,  202],
#           ...,
#           [  63,   71,  213,  ...,  190,  145,   68],
#           [   5,  585,   29,  ...,    0,    3,   49],
#           [ 135,   48,    0,  ...,    4,  928,   55]], device='cuda:0'),
#   tensor([ 92, 400,  12,  ...,  20,   9,  26], device='cuda:0')],
#  [tensor([[   3,   52,   14,  ...,   20,    9,   26],
#           [ 533,   73,    9,  ...,   88, 1927,  211],
#           [  31,  129, 1475,  ...,   20,    4, 1715],
#           ...,
#           [  22,   48,    2,  ..., 1986, 1616,  171],
#           [1278,    2, 4746,  ...,  105,  167,  168],
#           [  95,    0,   47,  ...,    0,    4,    3]], device='cuda:0'),
#   tensor([533,  73,   9,  ...,   3, 554,  55], device='cuda:0')],
#  [tensor([[  55,   30,   12,  ...,    3,  554,   55],
#           [  10,    5,   86,  ...,   24,   13,   35],
#           [  76,    2,    3,  ...,  128,   33,  106],
#           ...,
#           [   8,    0,   14,  ...,    4,    6,    8],
#           [   2,   74,    9,  ...,  159, 3748, 1537],
#           [ 280, 4684,   38,  ...,  540, 3941,    6]], device='cuda:0'),
#   tensor([ 10,   5,  86,  ...,   7,   3, 374], device='cuda:0')],
#  [tensor([[   4,  138,    7,  ...,    7,    3,  374],
#           [   5,   73,  114,  ...,    2,   33, 1745],
#           [1806,  383,    3,  ...,  238,    9,   85],
#           ...,
#           [ 843,   14,  525,  ...,  457,  110,    8],
#           [ 271,   25,    4,  ..., 3525,  125, 1007],
#           [   4,   80,    2,  ...,   21,   33,   66]], device='cuda:0'),
#   tensor([  5,  73, 114,  ..., 351, 481,   2], device='cuda:0')],
#  [tensor([[  24,   17, 2472,  ...,  351,  481,    2],
#           [ 688,    8,   32,  ...,    0,    8,  505],
#           [3789, 2452,    0,  ...,   27,  697,  273],
#           ...,
#           [ 837,   19,   41,  ..., 2971, 2422,   19],
#           [  15,    2,    4,  ...,   30,    3,    2],
#           [  31,  107,    5,  ...,  896,    2,   25]], device='cuda:0'),
#   tensor([ 688,    8,   32,  ...,  343,  107, 2268], device='cuda:0')],
#  [tensor([[1149,  339,   75,  ...,  343,  107, 2268],
#           [  31, 1152,  582,  ...,   18,    7,   66],
#           [1454,   12, 3877,  ...,    0,  114,    6],
#           ...,
#           [   0, 1163,    2,  ...,    6,  114,    0],
#           [   0,    5,  913,  ...,  182,  151,   23],
#           [   3, 2779,   27,  ..., 2283,    8, 3535]], device='cuda:0'),
#   tensor([  31, 1152,  582,  ...,    8,    0,    0], device='cuda:0')],
#  [tensor([[  42,  174,    4,  ...,    8,    0,    0],
#           [  39,  602,   24,  ...,  964, 1639,    4],
#           [  14,   44,  349,  ...,   11,   43,   50],
#           ...,
#           [3217, 3253,    2,  ...,    4,    3,   46],
#           [ 255,    0, 3880,  ...,   26,   24,   52],
#           [ 179,    8,  368,  ...,  195,   33,    4]], device='cuda:0'),
#   tensor([  39,  602,   24,  ...,   11, 1168,   33], device='cuda:0')],
#  [tensor([[ 308, 1571,   60,  ...,   11, 1168,   33],
#           [   3, 4683,  150,  ...,   21,    8,    9],
#           [  24,   16,  113,  ...,    6, 1096,    0],
#           ...,
#           [   2,  442,    2,  ...,  260, 4493, 3276],
#           [1148,   14,   25,  ...,  982,  232,   65],
#           [   0,  518,  293,  ...,  924,   85,   10]], device='cuda:0'),
#   tensor([   3, 4683,  150,  ..., 3929,   59,  530], device='cuda:0')],
#  [tensor([[ 233,   25,  474,  ..., 3929,   59,  530],
#           [ 444,    3,  102,  ...,    3, 3895,   54],
#           [  11,   14,  112,  ...,  115,    0,   13],
#           ...,
#           [ 797, 2781,    8,  ...,    2,    0,    4],
#           [ 844,   60,   37,  ...,  714,    6,   23],
#           [2185,  468,  505,  ...,    4,  207,    2]], device='cuda:0'),
#   tensor([444,   3, 102,  ...,   0,   7,   0], device='cuda:0')],
#  [tensor([[4642,  113,    5,  ...,    0,    7,    0],
#           [   5,   59, 1476,  ...,    6,  382,   13],
#           [  26, 1016,   49,  ..., 5409,   46,   17],
#           ...,
#           [  50,    9,  321,  ..., 4061,    0,    4],
#           [2752,    6,  359,  ..., 2544,    4,    0],
#           [ 545,  182,   21,  ...,   11,    5,    4]], device='cuda:0'),
#   tensor([   5,   59, 1476,  ...,   10,  259,    0], device='cuda:0')],
#  [tensor([[   6,  273,  406,  ...,   10,  259,    0],
#           [   0,   28, 1842,  ...,   16,  149,    4],
#           [   4,    2,    4,  ...,    0,    8,    5],
#           ...,
#           [ 356,    9,  146,  ...,    2,   56,    9],
#           [1220,  518,    0,  ...,    0,   10,   38],
#           [   5,   18,    5,  ..., 3604,    4,    7]], device='cuda:0'),
#   tensor([   0,   28, 1842,  ...,   12,   24,    2], device='cuda:0')],
#  [tensor([[ 598,    2, 4750,  ...,   12,   24,    2],
#           [   7,  137,   32,  ...,  175,   33,  197],
#           [ 747,    4,    0,  ...,  972, 5662, 2063],
#           ...,
#           [   5, 2453,   45,  ..., 3442,    4, 2527],
#           [  26, 1828, 1842,  ...,  239,    5,    4],
#           [ 211,   43,  758,  ...,   27,    0,   14]], device='cuda:0'),
#   tensor([  7, 137,  32,  ...,   3,  43,   0], device='cuda:0')],
#  [tensor([[  94, 1017,    4,  ...,    3,   43,    0],
#           [   2,   16,  146,  ...,   14,    2,    7],
#           [ 181,  379,    2,  ...,   25, 3576,  919],
#           ...,
#           [   6,    5,    5,  ..., 1460,   48,   20],
#           [1965,   40, 1841,  ...,   21,   48,   10],
#           [ 269, 3256, 2176,  ..., 2483,  389,    9]], device='cuda:0'),
#   tensor([   2,   16,  146,  ..., 2528,    0,  589], device='cuda:0')],
#  [tensor([[   8,    5,    8,  ..., 2528,    0,  589],
#           [3224, 2454,    2,  ...,   42, 1301,    3],
#           [  34,   51,  231,  ...,   39,    3,   79],
#           ...,
#           [  24,  573,   32,  ...,    0,   19,   91],
#           [ 255,    7,   11,  ...,    0,  206,   29],
#           [  14,   58,  173,  ...,   50,    0,   81]], device='cuda:0'),
#   tensor([3224, 2454,    2,  ...,   60,    4,  336], device='cuda:0')],
#  [tensor([[   9,    6,    2,  ...,   60,    4,  336],
#           [   6,  318, 2004,  ...,   10, 2344,    8],
#           [ 505,    4,  723,  ...,   41,    5,   36],
#           ...,
#           [  27,    3,   13,  ...,   13,   38,  812],
#           [  14,   10,   10,  ...,    2,    7,    5],
#           [   9, 2784,   16,  ..., 1315,    2,   74]], device='cuda:0'),
#   tensor([   6,  318, 2004,  ...,    9,   79, 2230], device='cuda:0')],
#  [tensor([[ 284,   29,  266,  ...,    9,   79, 2230],
#           [3226,  130,   21,  ...,   93, 1030,  130],
#           [  54,   61,   84,  ...,    0,  179,  210],
#           ...,
#           [ 596,   47,   29,  ...,    6,  463,  194],
#           [  27,    6,   72,  ...,  393,    4,   21],
#           [   3,  216,  696,  ..., 1989,   14,   14]], device='cuda:0'),
#   tensor([3226,  130,   21,  ...,  358,   17,    0], device='cuda:0')],
#  [tensor([[  19,    7,  240,  ...,  358,   17,    0],
#           [ 651,    6,    4,  ...,   44,    6,    4],
#           [ 118,  141,   24,  ...,    2,   88,    0],
#           ...,
#           [   4,    5,   23,  ...,  113,   30, 1068],
#           [2756, 1049,    6,  ..., 5641, 2836, 5966],
#           [   4,    8, 2476,  ..., 4390,   27,    5]], device='cuda:0'),
#   tensor([651,   6,   4,  ...,   5,  17,   0], device='cuda:0')],
#  [tensor([[   0,   59,    7,  ...,    5,   17,    0],
#           [ 142,  136,    0,  ...,  388,    6, 1623],
#           [3227,    3,    3,  ...,   66,  635,    4],
#           ...,
#           [ 374,   12,    2,  ...,   17,  287,  189],
#           [2188,  100, 1959,  ..., 2356,  487,   42],
#           [   4,   82,  564,  ...,    4,    2,   39]], device='cuda:0'),
#   tensor([142, 136,   0,  ...,  24, 277,  35], device='cuda:0')],
#  [tensor([[ 328,   11, 4762,  ...,   24,  277,   35],
#           [  27,    2,    3,  ...,   12,   17,  377],
#           [   3,  781,   19,  ...,  175,  135,    9],
#           ...,
#           [ 772, 3259,  390,  ...,  253,    0, 1860],
#           [3231,   10,   20,  ...,    2, 1296,   11],
#           [   7,    3,   34,  ...,  618,    7,    6]], device='cuda:0'),
#   tensor([ 27,   2,   3,  ..., 142,   6,  67], device='cuda:0')],
#  [tensor([[4653,  683,  318,  ...,  142,    6,   67],
#           [   5,   40,    4,  ...,   32, 3686,  310],
#           [   0, 1158,   24,  ...,   79,    8,  119],
#           ...,
#           [2762,   10,  216,  ...,  557,   61,   72],
#           [  80,   16,  179,  ...,   18,   30,  720],
#           [ 198,  266,    3,  ..., 3091,    0, 1043]], device='cuda:0'),
#   tensor([   5,   40,    4,  ..., 2691,   27,    3], device='cuda:0')],
#  [tensor([[   8,    8,   19,  ..., 2691,   27,    3],
#           [  37, 1098,   14,  ...,    0,    5,  396],
#           [  63,    4,    9,  ...,   13,   61,    4],
#           ...,
#           [  77,   36,  423,  ...,    0,    9,   45],
#           [   3,  504,  305,  ...,  812, 1897, 1715],
#           [ 426,   51,   12,  ...,   22,   28,    8]], device='cuda:0'),
#   tensor([  37, 1098,   14,  ...,    3,    6,   94], device='cuda:0')],
#  [tensor([[   2,   10, 1142,  ...,    3,    6,   94],
#           [  22,    3,   12,  ...,   12, 1750,   62],
#           [   0,   42,   86,  ...,  213,    0,  401],
#           ...,
#           [   9,   91,  188,  ...,   59,    0,  438],
#           [  35,   35,  341,  ...,    4,   27,   17],
#           [  72,    3,   23,  ...,   24,    3,   81]], device='cuda:0'),
#   tensor([ 22,   3,  12,  ...,  12,  10, 470], device='cuda:0')]]

# %%
x,y = next(iter(data_lm.train_dl))
example = x[:20,:10].cpu()
texts = pd.DataFrame([data_lm.train_ds.vocab.textify(l).split(' ') for l in example])
texts
# Out:
#              0            1        2          3             4           5  \
# 0        xxfld  protagonist    xxunk       into  occasionally       start
# 1            1           is      for       this         xxunk    planning
# 2           un        xxunk        a       film            in         and
# 3            -          her  massive          ,         other         not
# 4        xxunk        early   series   although      versions     filming
# 5            -         life       of     having            of       until
# 6   believable           as     gags        the           the  everything
# 7            !            a    built       main         story         has
# 8          meg      butcher     upon  character             .        come
# 9         ryan            .     gags          a         wells        down
# 10        does        weird        ,      drunk             '          on
# 11         n't        stuff      but        and   description           a
# 12        even            .    stops          a            of  storyboard
# 13        look         then    short    heroine           the           .
# 14         her        there        (     addict      martians         you
# 15       usual           's      for        did                certainly
# 16       xxunk          the      all        n't             a        have
# 17     lovable         core      the       come         giant         the
# 18        self      premise    xxunk         as          head     ability
# 19          in           of        )         an         xxunk         and
#
#            6          7         8          9
# 0      humor        his       the      xxunk
# 1         is    revenge       box         in
# 2        the          .    office         my
# 3    biggest      still         ,      xxunk
# 4    problem      alive     xxunk          .
# 5       with          ,        b.      first
# 6        the         it   demille          ,
# 7       film      looks   stopped        the
# 8          .       like     doing      xxunk
# 9       sure  carradine     films      scene
# 10         ,      tries     about    between
# 11    making         to       non        the
# 12       fun      shoot         -      women
# 13        of        her  american         at
# 14  mentally        and   history        the
# 15       ill     misses         .      xxunk
# 16    people          ,       his      xxunk
# 17        is        but     films         --
# 18    pretty         it       for  undertext
# 19       low       does       the          :

# %%
x[:,-1]
# Out:
# tensor([  27,   11,   80,    0,  389,    0,   30,   20, 1068,    0,   27, 1487,
#           61,    0,   61,    8, 1156,    2,  138,    7,    0,    0,   30,   20,
#            0, 4603,   27,    3,   19,   55,   26,  191,  182,  905,  116,   30,
#            7,   80,   52,   32, 5834,   48,   27,   12,  264,  333,   23,   61,
#          524,  905,   61,   30,    0,   27,    4,   61,  450,    7,    2, 1517,
#           61,   30,    0,   27,    4,   61,   12, 5108,   23,    6,  905,   61,
#           30,    0,   27,    4,   61,  398], device='cuda:0')

# %%
y.reshape((78,64))[:,-1]
# Out:
# tensor([  11,   80,    0,  389,    0,   30,   20, 1068,    0,   27, 1487,   61,
#            0,   61,    8, 1156,    2,  138,    7,    0,    0,   30,   20,    0,
#         4603,   27,    3,   19,   55,   26,  191,  182,  905,  116,   30,    7,
#           80,   52,   32, 5834,   48,   27,   12,  264,  333,   23,   61,  524,
#          905,   61,   30,    0,   27,    4,   61,  450,    7,    2, 1517,   61,
#           30,    0,   27,    4,   61,   12, 5108,   23,    6,  905,   61,   30,
#            0,   27,    4,   61,  398,    7], device='cuda:0')

# %%
# download_wt103_model()

# %%
learn = RNNLearner.language_model(data_lm, pretrained_fnames=['lstm_wt103', 'itos_wt103'], drop_mult=0.5)
# learn.load('../../interim/subset-10k/csv_test/models/10k-subset-5-epoch') # shouldn't work, as expected
# learn.fit_one_cycle(1, 1e-2)

# %%
with open('../data/imdb_sample/models/itos_wt103.pkl', 'rb') as f:
    aa = pickle.load(f)
aa = set(aa)
bb = data_lm.train_ds.vocab.itos
new_words = [w for w in bb if w not in aa]
new_words_id = data_lm.train_ds.vocab.numericalize(new_words)

# %%
new_words_id[-5:]
# Out:
# [5986, 5989, 5995, 5997, 5998]

# %%
learn.model.state_dict().get('0.encoder.weight')
# Out:
# tensor([[ 0.1810,  0.5646, -0.1060,  ...,  0.4994,  0.0770, -0.2302],
#         [ 0.1604,  0.4524,  0.0713,  ..., -0.0967, -0.1500, -0.2420],
#         [ 0.2266,  0.7696,  0.4682,  ..., -0.7127, -0.0354, -0.2544],
#         ...,
#         [ 0.1684,  0.4543,  0.0668,  ..., -0.1054, -0.1511, -0.2483],
#         [ 0.1753,  0.5136,  0.0942,  ..., -0.1172, -0.1426, -0.2452],
#         [ 0.1753,  0.5136,  0.0942,  ..., -0.1172, -0.1426, -0.2452]],
#        device='cuda:0')

# %%
learn.model.state_dict().get('1.decoder.weight')
# Out:
# tensor([[ 0.1810,  0.5646, -0.1060,  ...,  0.4994,  0.0770, -0.2302],
#         [ 0.1604,  0.4524,  0.0713,  ..., -0.0967, -0.1500, -0.2420],
#         [ 0.2266,  0.7696,  0.4682,  ..., -0.7127, -0.0354, -0.2544],
#         ...,
#         [ 0.1684,  0.4543,  0.0668,  ..., -0.1054, -0.1511, -0.2483],
#         [ 0.1753,  0.5136,  0.0942,  ..., -0.1172, -0.1426, -0.2452],
#         [ 0.1753,  0.5136,  0.0942,  ..., -0.1172, -0.1426, -0.2452]],
#        device='cuda:0')

# %%
learn.model.state_dict().keys()
# Out:
# odict_keys(['0.encoder.weight', '0.encoder_dp.emb.weight', '0.rnns.0.weight_hh_l0_raw', '0.rnns.0.module.weight_ih_l0', '0.rnns.0.module.weight_hh_l0', '0.rnns.0.module.bias_ih_l0', '0.rnns.0.module.bias_hh_l0', '0.rnns.1.weight_hh_l0_raw', '0.rnns.1.module.weight_ih_l0', '0.rnns.1.module.weight_hh_l0', '0.rnns.1.module.bias_ih_l0', '0.rnns.1.module.bias_hh_l0', '0.rnns.2.weight_hh_l0_raw', '0.rnns.2.module.weight_ih_l0', '0.rnns.2.module.weight_hh_l0', '0.rnns.2.module.bias_ih_l0', '0.rnns.2.module.bias_hh_l0', '1.decoder.weight', '1.decoder.bias'])

# %%
learn.model.state_dict().get('0.rnns.0.weight_hh_l0_raw')
# Out:
# tensor([[ 1.0887e-06, -3.4341e-05, -3.1302e-04,  ...,  7.9728e-05,
#          -2.2890e-04, -2.1083e-03],
#         [ 8.8435e-05,  1.2616e-03, -1.0472e-03,  ...,  1.2605e-04,
#          -1.4627e-04, -2.7947e-04],
#         [-2.3075e-04,  2.5539e-03,  3.1424e-04,  ...,  1.5183e-04,
#           4.2930e-04,  2.7320e-03],
#         ...,
#         [-7.6183e-05,  7.5574e-05, -4.4466e-04,  ...,  2.1551e-04,
#          -2.0065e-04, -1.9130e-03],
#         [-2.0353e-05,  9.8663e-04,  9.2116e-05,  ...,  1.4796e-04,
#          -7.3235e-05,  1.7084e-03],
#         [ 1.0952e-02, -1.4709e-02, -4.1601e-04,  ..., -1.0293e-02,
#           4.5011e-03,  7.4333e-02]], device='cuda:0')

# %%
learn.model
# Out:
# SequentialRNN(
#   (0): RNNCore(
#     (encoder): Embedding(5999, 400, padding_idx=1)
#     (encoder_dp): EmbeddingDropout(
#       (emb): Embedding(5999, 400, padding_idx=1)
#     )
#     (rnns): ModuleList(
#       (0): WeightDropout(
#         (module): LSTM(400, 1150)
#       )
#       (1): WeightDropout(
#         (module): LSTM(1150, 1150)
#       )
#       (2): WeightDropout(
#         (module): LSTM(1150, 400)
#       )
#     )
#     (input_dp): RNNDropout()
#     (hidden_dps): ModuleList(
#       (0): RNNDropout()
#       (1): RNNDropout()
#       (2): RNNDropout()
#     )
#   )
#   (1): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=5999, bias=True)
#     (output_dp): RNNDropout()
#   )
# )

# %%
learn.unfreeze()
learn.fit_one_cycle(1, 1e-6)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, max=1), HTML(value='0.00% [0/1 00:00<00:00]'))), HTML(value…
# Total time: 00:23
# epoch  train loss  valid loss  accuracy
# 0      4.543907    4.223047    0.244530  (00:23)

# %% [markdown]
# ## Generate Text?

# %%
import nltk
nltk.download('punkt')
from nltk import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to /home/syang/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
m.reset()

# %%
m = learn.model
s = word_tokenize('the thing')
t = LongTensor(data_lm.train_ds.vocab.numericalize(s)).view(-1,1).cuda()
t = torch.autograd.Variable(t)

# %%
# m.eval()
# res, *_ = m(t)
# # r = np.asarray(res[-1].detach().cpu())
# r = res[-1]
# sm = torch.nn.Softmax(dim=0)
# r = sm(r)
# r = np.asarray(r.detach().cpu())
# n = np.argmax(np.random.multinomial(1, r))
# word = data_lm.valid_ds.vocab.textify([n])
# n = LongTensor([n]).view(-1, 1).cuda()

# %%
# generation with multinomial
# there is some bug with torch library with torch.multinomial
# that throws and exception and make you restart the kernel
# reverting to numpy
m.eval()
for i in range(50):
    res, *_ = m(t)
    # r = np.asarray(res[-1].detach().cpu())
    r = res[-1]
    sm = torch.nn.Softmax(dim=0)
    r = sm(r)
    r = np.asarray(r.detach().cpu())
    n = np.argmax(np.random.multinomial(1, r))
    word = data_lm.valid_ds.vocab.textify([n])
    n = LongTensor([n]).view(-1, 1).cuda()
    print(word, end=' ')
    if word == '<eos>': break
    t = torch.cat((t, n))
# Out:
# is about this , since it 's xxunk . what , if you want real members of the society , in all of the supporting settings will take you " . since each member of the
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-a0dc32ee531d> in <module>()
#      11     r = sm(r)
#      12     r = np.asarray(r.detach().cpu())
# ---> 13     n = np.argmax(np.random.multinomial(1, r))
#      14     word = data_lm.valid_ds.vocab.textify([n])
#      15     n = LongTensor([n]).view(-1, 1).cuda()
#
# mtrand.pyx in mtrand.RandomState.multinomial()
#
# ValueError: sum(pvals[:-1]) > 1.0

# %%
# generation with top word
m.eval()
for i in range(100):
    res, *_ = m(t)
    n = res[-1].topk(10)[1]
    n = n[1] if n.data[0]==0 else n[0]
    word = data_lm.valid_ds.vocab.textify([n.item()])
    print(word, end=' ')
    if word == '<eos>': break
    t = torch.cat((t, n.unsqueeze(0).unsqueeze(0)))
# Out:
# been a matter of course , if not a matter of course , if the country is in a position to take a more active role in the country 's political and political life . the fact that the country is in a position to make a peace with the country is a matter of course . the country will be able to secure a peace with the country , and the country will be able to secure a peace with the country . the country will be able to secure a peace with the country , and the country

# %%
m
# Out:
# SequentialRNN(
#   (0): RNNCore(
#     (encoder): Embedding(5999, 400, padding_idx=1)
#     (encoder_dp): EmbeddingDropout(
#       (emb): Embedding(5999, 400, padding_idx=1)
#     )
#     (rnns): ModuleList(
#       (0): WeightDropout(
#         (module): LSTM(400, 1150)
#       )
#       (1): WeightDropout(
#         (module): LSTM(1150, 1150)
#       )
#       (2): WeightDropout(
#         (module): LSTM(1150, 400)
#       )
#     )
#     (input_dp): RNNDropout()
#     (hidden_dps): ModuleList(
#       (0): RNNDropout()
#       (1): RNNDropout()
#       (2): RNNDropout()
#     )
#   )
#   (1): LinearDecoder(
#     (decoder): Linear(in_features=400, out_features=5999, bias=True)
#     (output_dp): RNNDropout()
#   )
# )

# %%
from nltk import word_tokenize
m = learn.model
s = word_tokenize('/n the big red dock')
t = LongTensor(data_lm.train_ds.vocab.numericalize(s)).view(-1,1).cuda()

# %%
for i in range(50):
    res,*_ = m(t)
    n=res[-1].topk(2)[1]
    n = n[1] if n.data[0]==0 else n[0]
    word = data_lm.valid_ds.vocab.itos[n.item()]
    print(word, end=' ')
    if word == '<eos>': break
    t = torch.cat((t, n.unsqueeze(0).unsqueeze(0)))
# Out:
# - black . the black - white - white , white - white , and white - white - white , and the black - white - white , white - white , and white - collar white - collar white - collar white - collar white - collar white
